# %%
#4 условие

import numpy as npy

nw = 2
np = 5
nm = 10
nk = 2
nd = 6
nh = 8

x1 = npy.zeros(nw*nd*nh*np*nm*nk+10, dtype=int)
x2 = npy.zeros(nw*nd*nh*np*nm*nk+10, dtype=int)
x3 = npy.zeros(nw*nd*nh*np*nm*nk+10, dtype=int)
x4 = npy.zeros(nw*nd*nh*np*nm*nk+10, dtype=int)

def func(w,d,h,p,m,k):
  result = (1+(m-1)+(h-1)*nm+(d-1)*nm*nh+(p-1)*nd*nm*nh+(k-1)*nd*nm*nh*np+(w-1)*nd*nm*nh*np*nk)
  return result

p2 = 2
d2 = 1

p3 = 4
d3 = 2

p4 = 5
d4 = 2

p1 = 1
d1 = 3

for w in range(1, 3):
  for k in range(1, 3):
     for h in range(1, 9):
        for m in range(1, 11):
            ind = func(w,d1,h,p1,m,k)
            x1[ind-1]=1
for w in range(1, 3):
  for k in range(1, 3):
     for h in range(1, 9):
        for m in range(1, 11):
            ind = func(w,d2,h,p2,m,k)
            x2[ind-1]=1
for w in range(1, 3):
  for k in range(1, 3):
     for h in range(1, 9):
        for m in range(1, 11):
            ind = func(w,d3,h,p3,m,k)
            x3[ind-1]=1
for w in range(1, 3):
  for k in range(1, 3):
     for h in range(1, 9):
        for m in range(1, 11):
            ind = func(w,d4,h,p4,m,k)
            x4[ind-1]=1



matxxx = npy.diagflat(x1+x2+x3+x4)
with open('arr1.npy','wb') as f:
      npy.save(f,matxxx)

# %%
#7 условие

import numpy as npy

nw = 2
np = 5
nm = 10
nk = 2
nd = 6
nh = 8

mat_x = npy.zeros((nw*nd*nh*np*nm*nk+10,nw*nd*nh*np*nm*nk+10), dtype=int)

def func(w,d,h,p,m,k):
  result = (1+(m-1)+(h-1)*nm+(d-1)*nm*nh+(p-1)*nd*nm*nh+(k-1)*nd*nm*nh*np+(w-1)*nd*nm*nh*np*nk)
  return result

for k in range(1, nk+1):
  for kk in range(k+1, nk+1):
    for m in range(1, nm+1):
     for mm in range(m+1, nm+1):
      for w in range(1, 3):
        for p in range(1,6):
          for d in range(1,7):
            for h in range(1, 9):
              i=func(w,d,h,p,m,k)
              j=func(w,d,h,p,mm,kk)
              mat_x[i-1,j-1]=1
              mat_x[j-1,i-1]=1

with open('arr2.npy','wb') as f:
      npy.save(f,mat_x)

# %%
#6б условие
import numpy as npy
import itertools as it

nw = 2
np = 5
nm = 10
nk = 2
nd = 6
nh = 8

x1 = npy.zeros(nw*nd*nh*np*nm*nk+10, dtype=int)

def func(w,d,h,p,m,k):
  result = (1+(m-1)+(h-1)*nm+(d-1)*nm*nh+(p-1)*nd*nm*nh+(k-1)*nd*nm*nh*np+(w-1)*nd*nm*nh*np*nk)
  return result

for p in range(1, np+1):
  for m in it.chain(range(1,2*p-1),range(2*p+1,nm+1)):
    for w in range(1, nw+1):
      for k in range(1, nk+1):
        for d in range(1,nd+1):
          for h in range(1, nh+1):
            ind = func(w,d,h,p,m,k)
            x1[ind-1] = 1

matx5 = npy.diagflat(x1)

with open('arr3.npy','wb') as f:
      npy.save(f,matx5)

# %%
# 5 условие
import numpy as npy

nw = 2
np = 5
nm = 10
nk = 2
nd = 6
nh = 8

mat_x = npy.zeros((nw*nd*nh*np*nm*nk+10,nw*nd*nh*np*nm*nk+10), dtype=int)

def func(w,d,h,p,m,k):
  result = (1+(m-1)+(h-1)*nm+(d-1)*nm*nh+(p-1)*nd*nm*nh+(k-1)*nd*nm*nh*np+(w-1)*nd*nm*nh*np*nk)
  return result

for k in range(1,nk+1):
  for m in range(1,nm+1):
    for w in range(1, nw+1):
      for ww in range(w+1, nw+1):
        for p in range(1,np+1):
          for pp in range(p+1,np+1):
            for d in range(1,nd+1):
              for dd in range(d+1,nd+1):
                for h in range(1, nh+1):
                  for hh in range(h+1, nh+1):
                    i=func(w,d,h,p,m,k)
                    j=func(w,d,hh,pp,mm,kk)
                    mat_x[i-1,j-1]=1
                    mat_x[j-1,i-1]=1

mat_xx = mat_x - 7*npy.eye(nw*nd*nh*np*nm*nk+10, dtype=int)

with open('arr4.npy','wb') as f:
      npy.save(f,mat_xx)

# %%
#3 условие  условие
import numpy as npy

nw = 2
np = 5
nm = 10
nk = 2
nd = 6
nh = 8

mat_x = npy.zeros((nw*nd*nh*np*nm*nk,nw*nd*nh*np*nm*nk), dtype=int)

def func(w,d,h,p,m,k):
  result = (1+(m-1)+(h-1)*nm+(d-1)*nm*nh+(p-1)*nd*nm*nh+(k-1)*nd*nm*nh*np+(w-1)*nd*nm*nh*np*nk)
  return result

for w in range(1, nw+1):
  for k in range(1,nk+1):
    for d in range(1,nd+1):
      for m in range(1,nm+1):
        for h in range(1, nh+1):
          for hh in range(h+1, nh+1):
            for p in range(1,np+1):
              for pp in range(p+1,np+1):
                    i=func(w,d,h,p,m,k)
                    j=func(w,d,hh,pp,m,k)
                    mat_x[i-1,j-1]=1
                    mat_x[j-1,i-1]=1

mat_x = mat_x - 3*npy.eye(nw*nd*nh*np*nm*nk,dtype=int)


#добавление расширения для 2
matx = npy.zeros((nw*nd*nh*np*nm*nk+10,nw*nd*nh*np*nm*nk+10), dtype=int)

matx[0:9600,0:9600] = mat_x

npy.ones(nw*nd*nh*np*nm*nk, dtype=int)

matx[nw*nd*nh*np*nm*nk,:nw*nd*nh*np*nm*nk] = matx[nw*nd*nh*np*nm*nk,:nw*nd*nh*np*nm*nk]+ npy.ones(nw*nd*nh*np*nm*nk, dtype=int)

matx[nw*nd*nh*np*nm*nk+1,:nw*nd*nh*np*nm*nk] = matx[nw*nd*nh*np*nm*nk+1,:nw*nd*nh*np*nm*nk]+ 2*npy.ones(nw*nd*nh*np*nm*nk, dtype=int)

matx[:nw*nd*nh*np*nm*nk,nw*nd*nh*np*nm*nk] = matx[:nw*nd*nh*np*nm*nk,nw*nd*nh*np*nm*nk]+ npy.ones(nw*nd*nh*np*nm*nk, dtype=int)

matx[:nw*nd*nh*np*nm*nk,nw*nd*nh*np*nm*nk+1] = matx[:nw*nd*nh*np*nm*nk,nw*nd*nh*np*nm*nk+1]+ 2*npy.ones(nw*nd*nh*np*nm*nk, dtype=int)

m4 = nw*nd*nk*nm*npy.array([[-3, 2],[2, -4]])

matx[-10:-8,-10:-8]= m4

with open('arr5.npy','wb') as f:
      npy.save(f,matx)
#добавление расширения для 2

# %%
#2 условие  условие
import numpy as npy

nw = 2
np = 5
nm = 10
nk = 2
nd = 6
nh = 8

mat_x = npy.zeros((nw*nd*nh*np*nm*nk,nw*nd*nh*np*nm*nk), dtype=int)

def func(w,d,h,p,m,k):
  result = (1+(m-1)+(h-1)*nm+(d-1)*nm*nh+(p-1)*nd*nm*nh+(k-1)*nd*nm*nh*np+(w-1)*nd*nm*nh*np*nk)
  return result

for w in range(1, nw+1):
  for k in range(1,nk+1):
    for d in range(1,nd+1):
      for m in range(1,nm+1):
        for h in range(1, nh+1):
          for hh in range(h+1, nh+1):
            for p in range(1,np+1):
              for pp in range(p+1,np+1):
                    i=func(w,d,h,p,m,k)
                    j=func(w,d,hh,pp,m,k)
                    mat_x[i-1,j-1]=1
                    mat_x[j-1,i-1]=1

mat_x = mat_x - 3*npy.eye(nw*nd*nh*np*nm*nk,dtype=int)


#добавление расширения для 6
matx = npy.zeros((nw*nd*nh*np*nm*nk+10,nw*nd*nh*np*nm*nk+10), dtype=int)

matx[0:9600,0:9600] = mat_x

npy.ones(nw*nd*nh*np*nm*nk, dtype=int)
#---- строки
matx[nw*nd*nh*np*nm*nk+2,:nw*nd*nh*np*nm*nk] = matx[nw*nd*nh*np*nm*nk+2,:nw*nd*nh*np*nm*nk]+ npy.ones(nw*nd*nh*np*nm*nk, dtype=int)

matx[nw*nd*nh*np*nm*nk+3,:nw*nd*nh*np*nm*nk] = matx[nw*nd*nh*np*nm*nk+3,:nw*nd*nh*np*nm*nk]+ 2*npy.ones(nw*nd*nh*np*nm*nk, dtype=int)

matx[nw*nd*nh*np*nm*nk+4,:nw*nd*nh*np*nm*nk] = matx[nw*nd*nh*np*nm*nk+4,:nw*nd*nh*np*nm*nk]+ 4*npy.ones(nw*nd*nh*np*nm*nk, dtype=int)
#---- столбцы
matx[:nw*nd*nh*np*nm*nk,nw*nd*nh*np*nm*nk+2] = matx[:nw*nd*nh*np*nm*nk,nw*nd*nh*np*nm*nk+2]+ npy.ones(nw*nd*nh*np*nm*nk, dtype=int)

matx[:nw*nd*nh*np*nm*nk,nw*nd*nh*np*nm*nk+3] = matx[:nw*nd*nh*np*nm*nk,nw*nd*nh*np*nm*nk+3]+ 2*npy.ones(nw*nd*nh*np*nm*nk, dtype=int)

matx[:nw*nd*nh*np*nm*nk,nw*nd*nh*np*nm*nk+4] = matx[:nw*nd*nh*np*nm*nk,nw*nd*nh*np*nm*nk+4]+ 4*npy.ones(nw*nd*nh*np*nm*nk, dtype=int)

m4 = nw*nd*nk*npy.array([[-11, 2, 4],[2, -20, 8],[4, 8, -32]])

matx[-8:-5,-8:-5]= m4

with open('arr6.npy','wb') as f:
      npy.save(f,matx)

# %%
#6a условие  условие
import numpy as npy

nw = 2
np = 5
nm = 10
nk = 2
nd = 6
nh = 8

mat_x = npy.zeros((nw*nd*nh*np*nm*nk,nw*nd*nh*np*nm*nk), dtype=int)

def func(w,d,h,p,m,k):
  result = (1+(m-1)+(h-1)*nm+(d-1)*nm*nh+(p-1)*nd*nm*nh+(k-1)*nd*nm*nh*np+(w-1)*nd*nm*nh*np*nk)
  return result

for w in range(1, nw+1):
  for k in range(1,nk+1):
    for d in range(1,nd+1):
      for m in range(1,nm+1):
        for h in range(1, nh+1):
          for hh in range(h+1, nh+1):
            for p in range(1,np+1):
              for pp in range(p+1,np+1):
                    i=func(w,d,h,p,m,k)
                    j=func(w,d,hh,pp,m,k)
                    mat_x[i-1,j-1]=1
                    mat_x[j-1,i-1]=1

mat_x = mat_x - 3*npy.eye(nw*nd*nh*np*nm*nk,dtype=int)


#добавление расширения для 20
matx = npy.zeros((nw*nd*nh*np*nm*nk+10,nw*nd*nh*np*nm*nk+10), dtype=int)

matx[0:9600,0:9600] = mat_x

npy.ones(nw*nd*nh*np*nm*nk, dtype=int)
#---- строки
matx[nw*nd*nh*np*nm*nk+5,:nw*nd*nh*np*nm*nk] = matx[nw*nd*nh*np*nm*nk+5,:nw*nd*nh*np*nm*nk]+ npy.ones(nw*nd*nh*np*nm*nk, dtype=int)

matx[nw*nd*nh*np*nm*nk+6,:nw*nd*nh*np*nm*nk] = matx[nw*nd*nh*np*nm*nk+6,:nw*nd*nh*np*nm*nk]+ 2*npy.ones(nw*nd*nh*np*nm*nk, dtype=int)

matx[nw*nd*nh*np*nm*nk+7,:nw*nd*nh*np*nm*nk] = matx[nw*nd*nh*np*nm*nk+7,:nw*nd*nh*np*nm*nk]+ 4*npy.ones(nw*nd*nh*np*nm*nk, dtype=int)

matx[nw*nd*nh*np*nm*nk+8,:nw*nd*nh*np*nm*nk] = matx[nw*nd*nh*np*nm*nk+8,:nw*nd*nh*np*nm*nk]+ 8*npy.ones(nw*nd*nh*np*nm*nk, dtype=int)

matx[nw*nd*nh*np*nm*nk+9,:nw*nd*nh*np*nm*nk] = matx[nw*nd*nh*np*nm*nk+9,:nw*nd*nh*np*nm*nk]+ 16*npy.ones(nw*nd*nh*np*nm*nk, dtype=int)
#---- столбцы
matx[:nw*nd*nh*np*nm*nk,nw*nd*nh*np*nm*nk+5] = matx[:nw*nd*nh*np*nm*nk,nw*nd*nh*np*nm*nk+5]+ npy.ones(nw*nd*nh*np*nm*nk, dtype=int)

matx[:nw*nd*nh*np*nm*nk,nw*nd*nh*np*nm*nk+6] = matx[:nw*nd*nh*np*nm*nk,nw*nd*nh*np*nm*nk+6]+ 2*npy.ones(nw*nd*nh*np*nm*nk, dtype=int)

matx[:nw*nd*nh*np*nm*nk,nw*nd*nh*np*nm*nk+7] = matx[:nw*nd*nh*np*nm*nk,nw*nd*nh*np*nm*nk+7]+ 4*npy.ones(nw*nd*nh*np*nm*nk, dtype=int)

matx[:nw*nd*nh*np*nm*nk,nw*nd*nh*np*nm*nk+8] = matx[:nw*nd*nh*np*nm*nk,nw*nd*nh*np*nm*nk+8]+ 8*npy.ones(nw*nd*nh*np*nm*nk, dtype=int)

matx[:nw*nd*nh*np*nm*nk,nw*nd*nh*np*nm*nk+9] = matx[:nw*nd*nh*np*nm*nk,nw*nd*nh*np*nm*nk+9]+ 16*npy.ones(nw*nd*nh*np*nm*nk, dtype=int)

m4 = nw*np*npy.array([[-39, 2, 4, 8, 16],[2, -76, 8, 16 ,32],[4, 8, -144 ,32 ,64],[8, 16 ,32 ,-256,128],[16 ,32 ,64,128,-384]])

matx[-5:,-5:]= m4

with open('arr7.npy','wb') as f:
      npy.save(f,matx)

# %%
import pickle

P1 = 1
P2 = 10
P3 = 1
P4 = 1
P5 = 1
P6 = 1
P7 = 1

with open('arr1.npy','rb') as f:
  arr1 = npy.load(f)

with open('arr2.npy','rb') as f:
  arr2 = npy.load(f)

with open('arr3.npy','rb') as f:
  arr3 = npy.load(f)

with open('arr4.npy','rb') as f:
  arr4 = npy.load(f)

with open('arr5.npy','rb') as f:
  arr5 = npy.load(f)

with open('arr6.npy','rb') as f:
  arr6 = npy.load(f)

with open('arr7.npy','rb') as f:
  arr7 = npy.load(f)

finall_arr = P1*arr1+P2*arr2+P3*arr3+P4*arr4+P5*arr5+P6*arr6+P7*arr7


with open('finall_arr.pk', 'wb') as file: #не pickle, а pk
    pickle.dump(finall_arr, file)

# %%
# обратное преобразование из мультииндекса
#import numpy as npy

#nw = 2
#nm = 10
#nk = 2
#nd = 6
#nh = 8

#def func(w,d,h,p,m,k):
  #result = (1+(m-1)+(h-1)*nm+(d-1)*nm*nh+(p-1)*nd*nm*nh+(k-1)*nd*nm*nh*np+(w-1)*nd*nm*nh*np*nk)
  #return result

#multiind = []
#ind = []

#for w in range(1, nw+1):
    #for d in range(1, nd+1):
        #for k in range(1,nk+1):
            #for m in range(1,nm+1):
                #for h in range(1, nh+1):
                    #for p in range(1,np+1):
                        #multiind = multiind + [(w, d, h, p, m, k)]
                        #ind = ind + [func(w, d, h, p, m, k)]
                        #print((w, d, h, p, m, k),'-----',func(w, d, h, p, m, k))

# %%
#вывод финальных даннных

import numpy as npy

nw = 2
np = 5
nm = 10
nk = 2
nd = 6
nh = 8

def func(w,d,h,p,m,k):
  result = (1+(m-1)+(h-1)*nm+(d-1)*nm*nh+(p-1)*nd*nm*nh+(k-1)*nd*nm*nh*np+(w-1)*nd*nm*nh*np*nk)
  return result

supermassive = npy.zeros((9610,6), dtype = int)

for w in range(1, nw+1):
    for d in range(1, nd+1):
        for k in range(1,nk+1):
            for m in range(1,nm+1):
                for h in range(1, nh+1):
                    for p in range(1,np+1):
                        ind = func(w, d, h, p, m, k)
                        supermassive[ind] = npy.array([w, d, h, p, m, k])
                       #print((w, d, h, p, m, k),'-----',func(w, d, h, p, m, k))


def reader(word):
    ind = int(word.split(":")[0].split("_")[1])
    val = float(word.split(":")[1])
    return ind, val

with open("timetable_2500_100_out.txt","r") as file:
    lines=file.readlines()
    x = npy.zeros(len(lines))
    for line in lines:
      ind,wal=reader(line)
      x[ind]= wal

weeks = ["1 неделя", "2 неделя"]
days = ["пн","вт","ср","чт","пт","сб"]
hours = ["1","2","3","4","5","6","7","8"]
prep = ["Иванов","Петров","Сидоров","Карпов","Соколов"]
mudro = ["Квантовая механика","Квантовая теория информации","Квантовые вычислений","Сложность квантовых алгоитмов","Квантовые алг. в логистике","Квантовое масшинное обучение","Моделирование квант. систем", "Квант. алгоритмы в химии","Физическая реализация квант. компютеров","Моделирование квант. алгоритмов"]
groups = ["QC_1","QC_2"]

for ind, elmt in enumerate(x):
  if elmt == 1.0:
    w,d,h,p,m,k = supermassive[ind]
    print(groups[k-1],weeks[w-1],days[d-1],hours[h-1],mudro[m-1],prep[p-1])
# Out:
# QC_1 1 неделя пн 7 Квант. алгоритмы в химии Иванов
# QC_1 1 неделя пн 7 Физическая реализация квант. компютеров Иванов
# QC_1 1 неделя пн 7 Моделирование квант. алгоритмов Иванов
# QC_1 1 неделя пн 8 Квантовая механика Иванов
# QC_1 1 неделя пн 8 Квантовая теория информации Иванов
# QC_1 1 неделя пн 8 Квантовые вычислений Иванов
# QC_1 1 неделя пн 8 Сложность квантовых алгоитмов Иванов
# QC_1 1 неделя пн 8 Квантовые алг. в логистике Иванов
# QC_1 1 неделя пн 8 Квантовое масшинное обучение Иванов
# QC_1 1 неделя пн 8 Моделирование квант. систем Иванов
# QC_1 1 неделя пн 8 Квант. алгоритмы в химии Иванов
# QC_1 1 неделя пн 8 Физическая реализация квант. компютеров Иванов
# QC_1 1 неделя вт 6 Физическая реализация квант. компютеров Иванов
# QC_1 1 неделя вт 7 Квантовое масшинное обучение Иванов
# QC_1 1 неделя вт 7 Моделирование квант. систем Иванов
# QC_1 1 неделя вт 7 Квант. алгоритмы в химии Иванов
# QC_1 1 неделя вт 7 Физическая реализация квант. компютеров Иванов
# ...
